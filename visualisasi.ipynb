# %%
import matplotlib.pyplot as plt
from collections import Counter

# %%
# Data jumlah aplikasi per pemda (pemda dan jumlah aplikasinya)
pemda_batch_counts = {
    "Kota Ambon": 15,
    "Kabupaten Asahan": 4,
    "Kota Bandung": 11,
    "Kota Batam": 3,
    "Kota Batu": 16,
    "Kabupaten Bengkayang": 6,
    "Kabupaten Deiyai": 3,
    "Kabupaten Dompu": 3,
    "Provinsi Jambi": 8,
    "Provinsi Jawa Tengah": 6,
    "Kabupaten Jeneponto": 9,
    "Kota Kupang": 15,
    "Provinsi Lampung": 2,
    "Kabupaten Lebong": 11,
    "Kabupaten Luwu": 1,
    "Kota Makassar": 4,
    "Provinsi Maluku": 2,
    "Kabupaten Muko Muko": 1,
    "Kabupaten Natuna": 10,
    "Kabupaten Nganjuk": 9,
    "Kabupaten Pamekasan": 1,
    "Kota Pontianak": 5,
    "Kabupaten Samosir": 8,
    "Kota Serang": 1,
    "Kota Tarakan": 3,
    "Kota Tidore": 12,
    "Kabupaten Timor Tengah Utara": 7,
    "Kabupaten Wonosobo": 1,
    # Pemda tanpa aplikasi
    "Kabupaten Buru": 0,
    "Kabupaten Dairi": 0,
    "Kabupaten Gunung Mas": 0,
    "Kabupaten Karang Anyar": 0,
    "Kabupaten Kerinci": 0,
    "Kota Sorong": 0,
    "Kabupaten Tanah Tidung": 0,
}

# Data frekuensi jenis layanan dari hasil analisis
layanan_counter = Counter({
    "Layanan Publik Sektoral": 21,
    "Layanan Perencanaan": 13,
    "Layanan Pengaduan Pelayanan Publik": 12,
    "Layanan Kearsipan Dinamis": 10,
    "Layanan Akuntabilitas Kinerja Organisasi": 10,
    "Layanan Pengawasan Internal terkait Pemerintah": 8,
    "Layanan Keuangan": 7,
    "Layanan Kepegawaian": 6,
    "Layanan Pengadaan Barang dan Jasa": 5,
    "Layanan Jaringan Dokumentasi dan Informasi Hukum": 3,
    "Layanan Kinerja Pegawai": 3,
    "Layanan Data Terbuka": 2,
})
# Data sebaran sistem yang paling banyak digunakan
aplikasi_terbanyak = {
    "SRIKANDI": 11,
    "SIPD": 11,
    "SP4N LAPOR": 10,
    "SAKIP": 10,
    "SPIP": 7,
    "SISKEUDES": 6,
    "SIRUP": 5,
    "OSS": 5,
    "SIMPEG": 4,
    "PTSP": 3,
    "SIMRS": 3,
    "SIAK": 3,
    "JDIH": 3,
    "IKD": 2,
    "SI LPPD": 2,
    "Simda": 2,
    "SIPSN": 2,
    "Simantap": 2,
    "E-Kinerja": 2
}


layanan_per_pemda = {
    "Kabupaten Buru": 0,
    "Kabupaten Dairi": 0,
    "Kabupaten Gunung Mas": 0,
    "Kabupaten Karang Anyar": 0,
    "Kabupaten Kerinci": 0,
    "Kota Sorong": 0,
    "Kabupaten Tanah Tidung": 0,
    "Kota Ambon": 5,
    "Kabupaten Asahan": 3,
    "Kota Bandung": 6,
    "Kota Batam": 2,
    "Kota Batu": 7,
    "Kabupaten Bengkayang": 6,
    "Kabupaten Deiyai": 2,
    "Kabupaten Dompu": 3,
    "Provinsi Jambi": 3,
    "Provinsi Jawa Tengah": 3,
    "Kabupaten Jeneponto": 6,
    "Kota Kupang": 7,
    "Provinsi Lampung": 2,
    "Kabupaten Lebong": 7,
    "Kabupaten Luwu": 1,
    "Kota Makassar": 4,
    "Provinsi Maluku": 2,
    "Kabupaten Muko Muko": 1,
    "Kabupaten Natuna": 7,
    "Kabupaten Nganjuk": 5,
    "Kabupaten Pamekasan": 1,
    "Kota Pontianak": 3,
    "Kabupaten Samosir": 5,
    "Kota Serang": 1,
    "Kota Tarakan": 2,
    "Kota Tidore": 6,
    "Kabupaten Timor Tengah Utara": 7,
    "Kabupaten Wonosobo": 1,
}

# %%
# 1. Visualisasi Jumlah Aplikasi tiap Pemerintah Daerah
fig1, ax1 = plt.subplots(figsize=(12, 10))
sorted_pemda = dict(sorted(pemda_batch_counts.items(), key=lambda x: x[1], reverse=True))
ax1.barh(list(sorted_pemda.keys()), list(sorted_pemda.values()), color='skyblue')
ax1.set_title("Visualisasi Jumlah Aplikasi tiap Pemerintah Daerah", fontsize=14)
ax1.set_xlabel("Jumlah Aplikasi")
ax1.set_ylabel("Pemerintah Daerah")
plt.tight_layout()
plt.show()

# %%
# 2. Visualisasi Frekuensi Jenis Layanan Pemerintah Daerah
fig2, ax2 = plt.subplots(figsize=(10, 7))
sorted_layanan = dict(sorted(layanan_counter.items(), key=lambda x: x[1], reverse=True))
ax2.barh(list(sorted_layanan.keys()), list(sorted_layanan.values()), color='mediumseagreen')
ax2.set_title("Frekuensi Jenis Layanan Pemerintah Daerah", fontsize=14)
ax2.set_xlabel("Jumlah Kemunculan")
ax2.set_ylabel("Jenis Layanan")
plt.tight_layout()
plt.show()

# %%
# 3. Visualisasi Sebaran Nama Aplikasi yang Paling Banyak Dimiliki Pemerintah Daerah
fig3, ax3 = plt.subplots(figsize=(8, 5))
sorted_apps = dict(sorted(aplikasi_terbanyak.items(), key=lambda x: x[1], reverse=True))
ax3.barh(list(sorted_apps.keys()), list(sorted_apps.values()), color='coral')
ax3.set_title("Sebaran Nama Aplikasi yang Paling Banyak Dimiliki Pemerintah Daerah", fontsize=13)
ax3.set_xlabel("Jumlah Pemerintah Daerah")
ax3.set_ylabel("Nama Aplikasi")
plt.tight_layout()
plt.show()

# %%
# Visualisasi
fig, ax = plt.subplots(figsize=(12, 10))
sorted_layanan_pemda = dict(sorted(layanan_per_pemda.items(), key=lambda x: x[1], reverse=True))
ax.barh(list(sorted_layanan_pemda.keys()), list(sorted_layanan_pemda.values()), color='slateblue')
ax.set_title("Jumlah Jenis Layanan tiap Pemerintah Daerah", fontsize=14)
ax.set_xlabel("Jumlah Jenis Layanan")
ax.set_ylabel("Pemerintah Daerah")
plt.tight_layout()
plt.show()
